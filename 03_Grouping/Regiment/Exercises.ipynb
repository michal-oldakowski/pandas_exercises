# %% [markdown]
# # Regiment

# %% [markdown]
# ### Introduction:
#
# Special thanks to: http://chrisalbon.com/ for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Create the DataFrame with the following values:

# %%
raw_data = {'regiment': ['Nighthawks', 'Nighthawks', 'Nighthawks', 'Nighthawks', 'Dragoons', 'Dragoons', 'Dragoons', 'Dragoons', 'Scouts', 'Scouts', 'Scouts', 'Scouts'], 
        'company': ['1st', '1st', '2nd', '2nd', '1st', '1st', '2nd', '2nd','1st', '1st', '2nd', '2nd'], 
        'name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze', 'Jacon', 'Ryaner', 'Sone', 'Sloan', 'Piger', 'Riani', 'Ali'], 
        'preTestScore': [4, 24, 31, 2, 3, 4, 24, 31, 2, 3, 2, 3],
        'postTestScore': [25, 94, 57, 62, 70, 25, 94, 57, 62, 70, 62, 70]}

# %% [markdown]
# ### Step 3. Assign it to a variable called regiment.
# #### Don't forget to name each column

# %%
regiment = pd.DataFrame(raw_data)

# %% [markdown]
# ### Step 4. What is the mean preTestScore from the regiment Nighthawks?

# %%
regiment[regiment['regiment']=='Nighthawks'].groupby('regiment').agg(
    mean_preTestScore = ('preTestScore', 'mean')
)
# Out:
#             mean_preTestScore
# regiment
# Nighthawks              15.25

# %% [markdown]
# ### Step 5. Present general statistics by company

# %%
regiment['company'].describe()
# Out:
# count      12
# unique      2
# top       1st
# freq        6
# Name: company, dtype: object

# %%
regiment.groupby('company')[['preTestScore', 'postTestScore']].agg(['mean', 'min', 'max', 'std'])
# Out:
#         preTestScore                    postTestScore
#                 mean min max        std          mean min max        std
# company
# 1st         6.666667   2  24   8.524475     57.666667  25  94  27.485754
# 2nd        15.500000   2  31  14.652645     67.000000  57  94  14.057027

# %% [markdown]
# ### Step 6. What is the mean of each company's preTestScore?

# %%
regiment.groupby('company')['preTestScore'].agg(['mean'])
# Out:
#               mean
# company
# 1st       6.666667
# 2nd      15.500000

# %% [markdown]
# ### Step 7. Present the mean preTestScores grouped by regiment and company

# %%
regiment.groupby(['regiment', 'company'])['preTestScore'].agg(['mean'])
# Out:
#                     mean
# regiment   company
# Dragoons   1st       3.5
#            2nd      27.5
# Nighthawks 1st      14.0
#            2nd      16.5
# Scouts     1st       2.5
#            2nd       2.5

# %% [markdown]
# ### Step 8. Present the mean preTestScores grouped by regiment and company without heirarchical indexing

# %%
regiment.groupby(['regiment', 'company'], as_index=False)['preTestScore'].agg(['mean'])
# Out:
#      regiment company  mean
# 0    Dragoons     1st   3.5
# 1    Dragoons     2nd  27.5
# 2  Nighthawks     1st  14.0
# 3  Nighthawks     2nd  16.5
# 4      Scouts     1st   2.5
# 5      Scouts     2nd   2.5

# %% [markdown]
# ### Step 9. Group the entire dataframe by regiment and company

# %%
grouped = regiment.groupby(['regiment', 'company'])

# %% [markdown]
# ### Step 10. What is the number of observations in each regiment and company

# %%
grouped = regiment.groupby(['regiment', 'company']).size()
grouped
# Out:
# regiment    company
# Dragoons    1st        2
#             2nd        2
# Nighthawks  1st        2
#             2nd        2
# Scouts      1st        2
#             2nd        2
# dtype: int64

# %% [markdown]
# ### Step 11. Iterate over a group and print the name and the whole data from the regiment

# %%
grouped = regiment.groupby('regiment')
for name, group in grouped['regiment']:
    print(name)
    print(group)
# Out:
# Dragoons
# 4    Dragoons
# 5    Dragoons
# 6    Dragoons
# 7    Dragoons
# Name: regiment, dtype: object
# Nighthawks
# 0    Nighthawks
# 1    Nighthawks
# 2    Nighthawks
# 3    Nighthawks
# Name: regiment, dtype: object
# Scouts
# 8     Scouts
# 9     Scouts
# 10    Scouts
# 11    Scouts
# Name: regiment, dtype: object
