# %% [markdown]
# # Investor - Flow of Funds - US

# %% [markdown]
# ### Introduction:
#
# Special thanks to: https://github.com/rgrp for sharing the dataset.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/datasets/investor-flow-of-funds-us/master/data/weekly.csv).

# %%
url = 'https://raw.githubusercontent.com/datasets/investor-flow-of-funds-us/master/data/weekly.csv'

# %% [markdown]
# ### Step 3. Assign it to a variable called

# %%
called = pd.read_csv(url)

# %% [markdown]
# ### Step 4.  What is the frequency of the dataset?

# %%
called['Date'].diff().value_counts()
# Out:
# Date
# 7 days      128
# 6 days        8
# 8 days        7
# 337 days      3
# 343 days      2
# 371 days      2
# 5 days        2
# 42 days       1
# 315 days      1
# 308 days      1
# 554 days      1
# 35 days       1
# 133 days      1
# Name: count, dtype: int64

# %% [markdown]
# ### Step 5. Set the column Date as the index.

# %%
called = called.set_index(called['Date'])

# %% [markdown]
# ### Step 6. What is the type of the index?

# %%
type(called.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %% [markdown]
# ### Step 7. Set the index to a DatetimeIndex type

# %%
called
# Out:
#                  Date  Total Equity  Domestic Equity  World Equity  Hybrid  \
# Date
# 2011-10-05 2011-10-05         -4002          -4499.0           497 -1354.0
# 2011-10-12 2011-10-12         -7397          -5842.0         -1555   512.0
# 2011-10-19 2011-10-19         -3292          -3466.0           174  1399.0
# 2011-10-26 2011-10-26         -3696          -2998.0          -698  2631.0
# 2011-12-07 2011-12-07         -7956          -5761.0         -2196  1089.0
# ...               ...           ...              ...           ...     ...
# 2024-12-04 2024-12-04         27170              NaN         22014     NaN
# 2024-12-11 2024-12-11         36551              NaN         28883     NaN
# 2024-12-18 2024-12-18         23053              NaN         27124     NaN
# 2024-12-24 2024-12-24         35211              NaN         36142     NaN
# 2024-12-31 2024-12-31         26027              NaN         21578     NaN
#
#             Total Bond  Taxable Bond  Municipal Bond    Total
# Date
# 2011-10-05       -5828       -6258.0             430 -11184.0
# 2011-10-12        3954        3927.0              28  -2931.0
# 2011-10-19        5652        5102.0             550   3759.0
# 2011-10-26        4910        4070.0             841   3846.0
# 2011-12-07        3523        2068.0            1456  -3343.0
# ...                ...           ...             ...      ...
# 2024-12-04       22510           NaN            -496      NaN
# 2024-12-11       29251           NaN            -368      NaN
# 2024-12-18       20767           NaN            6358      NaN
# 2024-12-24       32529           NaN            3613      NaN
# 2024-12-31       19932           NaN            1646      NaN
#
# [159 rows x 9 columns]

# %% [markdown]
# ### Step 8.  Change the frequency to monthly, sum the values and assign it to monthly.

# %%
monthly = called.select_dtypes(include='number').resample('ME').sum()
monthly
# Out:
#             Total Equity  Domestic Equity  World Equity  Hybrid  Total Bond  \
# Date
# 2011-10-31        -18387         -16805.0         -1582  3188.0        8688
# 2011-11-30             0              0.0             0     0.0           0
# 2011-12-31        -23657         -16659.0         -6999  2395.0       13817
# 2012-01-31             0              0.0             0     0.0           0
# 2012-02-29             0              0.0             0     0.0           0
# ...                  ...              ...           ...     ...         ...
# 2024-08-31             0              0.0             0     0.0           0
# 2024-09-30             0              0.0             0     0.0           0
# 2024-10-31             0              0.0             0     0.0           0
# 2024-11-30             0              0.0             0     0.0           0
# 2024-12-31        148012              0.0        135741     0.0      124989
#
#             Taxable Bond  Municipal Bond   Total
# Date
# 2011-10-31        6841.0            1849 -6510.0
# 2011-11-30           0.0               0     0.0
# 2011-12-31        9335.0            4483 -7443.0
# 2012-01-31           0.0               0     0.0
# 2012-02-29           0.0               0     0.0
# ...                  ...             ...     ...
# 2024-08-31           0.0               0     0.0
# 2024-09-30           0.0               0     0.0
# 2024-10-31           0.0               0     0.0
# 2024-11-30           0.0               0     0.0
# 2024-12-31           0.0           10753     0.0
#
# [159 rows x 8 columns]

# %% [markdown]
# ### Step 9. You will notice that it filled the dataFrame with months that don't have any data with NaN. Let's drop these rows.

# %%
called = called.dropna()

# %% [markdown]
# ### Step 10. Good, now we have the monthly data. Now change the frequency to year.

# %%
yearly = monthly.resample('YE').sum()
yearly
# Out:
#             Total Equity  Domestic Equity  World Equity   Hybrid  Total Bond  \
# Date
# 2011-12-31        -42044         -33464.0         -8581   5583.0       22505
# 2012-12-31        -23929         -22012.0         -1915    785.0        9828
# 2013-12-31          8052          -5562.0         13615   4180.0      -24460
# 2014-12-31        -17011         -15124.0         -1887  -6141.0      -14400
# 2015-12-31        -36337         -25116.0        -11221 -12474.0      -28678
# 2016-12-31             0              0.0             0      0.0           0
# 2017-12-31        -51270         -54927.0          3657 -10514.0       26158
# 2018-12-31             0              0.0             0      0.0           0
# 2019-12-31        -58200         -48830.0         -9370 -10874.0       37307
# 2020-12-31        -66618         -40387.0        -26231  -2972.0       60423
# 2021-12-31             0              0.0             0      0.0           0
# 2022-12-31        303756              0.0        197394      0.0      159480
# 2023-12-31        577223              0.0        384010      0.0      301841
# 2024-12-31        649190              0.0        498211      0.0      437265
#
#             Taxable Bond  Municipal Bond    Total
# Date
# 2011-12-31       16176.0            6332 -13953.0
# 2012-12-31       12491.0           -2663 -13316.0
# 2013-12-31      -14209.0          -10251 -12227.0
# 2014-12-31      -19014.0            4614 -37552.0
# 2015-12-31      -34571.0            5893 -77489.0
# 2016-12-31           0.0               0      0.0
# 2017-12-31       26360.0            -204 -35625.0
# 2018-12-31           0.0               0      0.0
# 2019-12-31       20486.0           16820 -31766.0
# 2020-12-31       50781.0            9643  -9170.0
# 2021-12-31           0.0               0      0.0
# 2022-12-31           0.0           37913      0.0
# 2023-12-31           0.0           82166      0.0
# 2024-12-31           0.0           60944      0.0

# %% [markdown]
# ### BONUS: Create your own question and answer it.
